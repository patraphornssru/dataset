# %% [markdown]
# 3/11/66 อัตราการว่างงาน

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
df = pd.read_csv('data_unemployment.csv')

# %%
df
# Out:
#       year      quarter    region    age_group             labor_force_sta  \
# 0     2561  ไตรมาสที่ 3  ภาคเหนือ  60 ปีขึ้นไป                         รวม
# 1     2561  ไตรมาสที่ 3  ภาคเหนือ  60 ปีขึ้นไป                     หางานทำ
# 2     2561  ไตรมาสที่ 3  ภาคเหนือ  60 ปีขึ้นไป  ไม่หางานทำ/พร้อมที่จะทำงาน
# 3     2561  ไตรมาสที่ 4  ภาคเหนือ  60 ปีขึ้นไป                         รวม
# 4     2561  ไตรมาสที่ 4  ภาคเหนือ  60 ปีขึ้นไป                     หางานทำ
# ...    ...          ...       ...          ...                         ...
# 5432  2562     ไตรมาส 4    ภาคใต้          NaN                นอกเขตเทศบาล
# 5433  2563     ไตรมาส 1    ภาคใต้          NaN                นอกเขตเทศบาล
# 5434  2563     ไตรมาส 2    ภาคใต้          NaN                นอกเขตเทศบาล
# 5435  2563     ไตรมาส 3    ภาคใต้          NaN                นอกเขตเทศบาล
# 5436  2563     ไตรมาส 4    ภาคใต้          NaN                นอกเขตเทศบาล
#
#       value   unit                 source
# 0      0.37  พันคน  สำนักงานสถิติแห่งชาติ
# 1      0.17  พันคน  สำนักงานสถิติแห่งชาติ
# 2      0.20  พันคน  สำนักงานสถิติแห่งชาติ
# 3      1.83  พันคน  สำนักงานสถิติแห่งชาติ
# 4      0.11  พันคน  สำนักงานสถิติแห่งชาติ
# ...     ...    ...                    ...
# 5432  69.12  พันคน  สำนักงานสถิติแห่งชาติ
# 5433  51.91  พันคน  สำนักงานสถิติแห่งชาติ
# 5434  67.12  พันคน  สำนักงานสถิติแห่งชาติ
# 5435  86.27  พันคน  สำนักงานสถิติแห่งชาติ
# 5436  96.14  พันคน  สำนักงานสถิติแห่งชาติ
#
# [5437 rows x 8 columns]

# %%
df['age_group'] = df['age_group'].str.extract('(\d+)').fillna(0).astype('int64')

# %%
df
# Out:
#       year      quarter    region  age_group             labor_force_sta  \
# 0     2561  ไตรมาสที่ 3  ภาคเหนือ         60                         รวม
# 1     2561  ไตรมาสที่ 3  ภาคเหนือ         60                     หางานทำ
# 2     2561  ไตรมาสที่ 3  ภาคเหนือ         60  ไม่หางานทำ/พร้อมที่จะทำงาน
# 3     2561  ไตรมาสที่ 4  ภาคเหนือ         60                         รวม
# 4     2561  ไตรมาสที่ 4  ภาคเหนือ         60                     หางานทำ
# ...    ...          ...       ...        ...                         ...
# 5432  2562     ไตรมาส 4    ภาคใต้          0                นอกเขตเทศบาล
# 5433  2563     ไตรมาส 1    ภาคใต้          0                นอกเขตเทศบาล
# 5434  2563     ไตรมาส 2    ภาคใต้          0                นอกเขตเทศบาล
# 5435  2563     ไตรมาส 3    ภาคใต้          0                นอกเขตเทศบาล
# 5436  2563     ไตรมาส 4    ภาคใต้          0                นอกเขตเทศบาล
#
#       value   unit                 source
# 0      0.37  พันคน  สำนักงานสถิติแห่งชาติ
# 1      0.17  พันคน  สำนักงานสถิติแห่งชาติ
# 2      0.20  พันคน  สำนักงานสถิติแห่งชาติ
# 3      1.83  พันคน  สำนักงานสถิติแห่งชาติ
# 4      0.11  พันคน  สำนักงานสถิติแห่งชาติ
# ...     ...    ...                    ...
# 5432  69.12  พันคน  สำนักงานสถิติแห่งชาติ
# 5433  51.91  พันคน  สำนักงานสถิติแห่งชาติ
# 5434  67.12  พันคน  สำนักงานสถิติแห่งชาติ
# 5435  86.27  พันคน  สำนักงานสถิติแห่งชาติ
# 5436  96.14  พันคน  สำนักงานสถิติแห่งชาติ
#
# [5437 rows x 8 columns]

# %%
average_age_group = int(df['age_group'].mean())
df['age_group'] = df['age_group'].replace(0, average_age_group)
df
# Out:
#       year      quarter    region  age_group             labor_force_sta  \
# 0     2561  ไตรมาสที่ 3  ภาคเหนือ         60                         รวม
# 1     2561  ไตรมาสที่ 3  ภาคเหนือ         60                     หางานทำ
# 2     2561  ไตรมาสที่ 3  ภาคเหนือ         60  ไม่หางานทำ/พร้อมที่จะทำงาน
# 3     2561  ไตรมาสที่ 4  ภาคเหนือ         60                         รวม
# 4     2561  ไตรมาสที่ 4  ภาคเหนือ         60                     หางานทำ
# ...    ...          ...       ...        ...                         ...
# 5432  2562     ไตรมาส 4    ภาคใต้         26                นอกเขตเทศบาล
# 5433  2563     ไตรมาส 1    ภาคใต้         26                นอกเขตเทศบาล
# 5434  2563     ไตรมาส 2    ภาคใต้         26                นอกเขตเทศบาล
# 5435  2563     ไตรมาส 3    ภาคใต้         26                นอกเขตเทศบาล
# 5436  2563     ไตรมาส 4    ภาคใต้         26                นอกเขตเทศบาล
#
#       value   unit                 source
# 0      0.37  พันคน  สำนักงานสถิติแห่งชาติ
# 1      0.17  พันคน  สำนักงานสถิติแห่งชาติ
# 2      0.20  พันคน  สำนักงานสถิติแห่งชาติ
# 3      1.83  พันคน  สำนักงานสถิติแห่งชาติ
# 4      0.11  พันคน  สำนักงานสถิติแห่งชาติ
# ...     ...    ...                    ...
# 5432  69.12  พันคน  สำนักงานสถิติแห่งชาติ
# 5433  51.91  พันคน  สำนักงานสถิติแห่งชาติ
# 5434  67.12  พันคน  สำนักงานสถิติแห่งชาติ
# 5435  86.27  พันคน  สำนักงานสถิติแห่งชาติ
# 5436  96.14  พันคน  สำนักงานสถิติแห่งชาติ
#
# [5437 rows x 8 columns]

# %%
df = df.drop('unit', axis=1)
df
# Out:
#       year      quarter    region  age_group             labor_force_sta  \
# 0     2561  ไตรมาสที่ 3  ภาคเหนือ         60                         รวม
# 1     2561  ไตรมาสที่ 3  ภาคเหนือ         60                     หางานทำ
# 2     2561  ไตรมาสที่ 3  ภาคเหนือ         60  ไม่หางานทำ/พร้อมที่จะทำงาน
# 3     2561  ไตรมาสที่ 4  ภาคเหนือ         60                         รวม
# 4     2561  ไตรมาสที่ 4  ภาคเหนือ         60                     หางานทำ
# ...    ...          ...       ...        ...                         ...
# 5432  2562     ไตรมาส 4    ภาคใต้         26                นอกเขตเทศบาล
# 5433  2563     ไตรมาส 1    ภาคใต้         26                นอกเขตเทศบาล
# 5434  2563     ไตรมาส 2    ภาคใต้         26                นอกเขตเทศบาล
# 5435  2563     ไตรมาส 3    ภาคใต้         26                นอกเขตเทศบาล
# 5436  2563     ไตรมาส 4    ภาคใต้         26                นอกเขตเทศบาล
#
#       value                 source
# 0      0.37  สำนักงานสถิติแห่งชาติ
# 1      0.17  สำนักงานสถิติแห่งชาติ
# 2      0.20  สำนักงานสถิติแห่งชาติ
# 3      1.83  สำนักงานสถิติแห่งชาติ
# 4      0.11  สำนักงานสถิติแห่งชาติ
# ...     ...                    ...
# 5432  69.12  สำนักงานสถิติแห่งชาติ
# 5433  51.91  สำนักงานสถิติแห่งชาติ
# 5434  67.12  สำนักงานสถิติแห่งชาติ
# 5435  86.27  สำนักงานสถิติแห่งชาติ
# 5436  96.14  สำนักงานสถิติแห่งชาติ
#
# [5437 rows x 7 columns]

# %%
df.shape
# Out:
# (5437, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5437 entries, 0 to 5436
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   year             5437 non-null   int64
#  1   quarter          5437 non-null   object
#  2   region           5437 non-null   object
#  3   age_group        5437 non-null   int64
#  4   labor_force_sta  5437 non-null   object
#  5   value            5437 non-null   float64
#  6   source           5437 non-null   object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 297.5+ KB

# %%
df.describe()
# Out:
#               year    age_group        value
# count  5437.000000  5437.000000  5437.000000
# mean   2559.471032    31.696892    28.473962
# std       2.328546    12.410908    61.494425
# min    2555.000000    15.000000     0.010000
# 25%    2557.000000    25.000000     2.400000
# 50%    2559.000000    26.000000     7.490000
# 75%    2561.000000    40.000000    26.810000
# max    2563.000000    60.000000   745.180000

# %%
df.isnull().sum()
# Out:
# year               0
# quarter            0
# region             0
# age_group          0
# labor_force_sta    0
# value              0
# source             0
# dtype: int64

# %%
df['value'] = df['value'] * 1000
df
# Out:
#       year      quarter    region  age_group             labor_force_sta  \
# 0     2561  ไตรมาสที่ 3  ภาคเหนือ         60                         รวม
# 1     2561  ไตรมาสที่ 3  ภาคเหนือ         60                     หางานทำ
# 2     2561  ไตรมาสที่ 3  ภาคเหนือ         60  ไม่หางานทำ/พร้อมที่จะทำงาน
# 3     2561  ไตรมาสที่ 4  ภาคเหนือ         60                         รวม
# 4     2561  ไตรมาสที่ 4  ภาคเหนือ         60                     หางานทำ
# ...    ...          ...       ...        ...                         ...
# 5432  2562     ไตรมาส 4    ภาคใต้         26                นอกเขตเทศบาล
# 5433  2563     ไตรมาส 1    ภาคใต้         26                นอกเขตเทศบาล
# 5434  2563     ไตรมาส 2    ภาคใต้         26                นอกเขตเทศบาล
# 5435  2563     ไตรมาส 3    ภาคใต้         26                นอกเขตเทศบาล
# 5436  2563     ไตรมาส 4    ภาคใต้         26                นอกเขตเทศบาล
#
#         value                 source
# 0       370.0  สำนักงานสถิติแห่งชาติ
# 1       170.0  สำนักงานสถิติแห่งชาติ
# 2       200.0  สำนักงานสถิติแห่งชาติ
# 3      1830.0  สำนักงานสถิติแห่งชาติ
# 4       110.0  สำนักงานสถิติแห่งชาติ
# ...       ...                    ...
# 5432  69120.0  สำนักงานสถิติแห่งชาติ
# 5433  51910.0  สำนักงานสถิติแห่งชาติ
# 5434  67120.0  สำนักงานสถิติแห่งชาติ
# 5435  86270.0  สำนักงานสถิติแห่งชาติ
# 5436  96140.0  สำนักงานสถิติแห่งชาติ
#
# [5437 rows x 7 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# สร้างแผนภูมิ Boxplot โดยใช้ Seaborn
plt.figure(figsize=(12, 8))
sns.boxplot(data=df, orient="h")  # orient="h" หมายถึงแสดงแนวนอน
plt.title('Boxplot for All Columns')
plt.show()

# %%
grouped = df.groupby('year')['value'].sum()
# สร้างกราฟแท่ง
plt.figure(figsize=(10, 6))
grouped.plot(kind='bar', color='skyblue')
plt.title('Yearly Unemployment Rate')
plt.xlabel('Year')
plt.ylabel('Unemployment Rate')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['value'],bins=80)
plt.title('Unemployment rate classified by value', fontsize=10)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['age_group'],bins=80)
plt.title('Unemployment rate classified by age group', fontsize=10)
plt.show()

# %%
df2 = df.groupby(['age_group'])['age_group'].count()
df2
# Out:
# age_group
# 15     551
# 20     576
# 25     573
# 26    1151
# 30     561
# 35     550
# 40     557
# 50     514
# 60     404
# Name: age_group, dtype: int64

# %%
duplicates = df[df.duplicated()]
duplicates
# Out:
# Empty DataFrame
# Columns: [year, quarter, region, age_group, labor_force_sta, value, source]
# Index: []

# %%
df2 = df.groupby(['region'])['region'].count()
df2
# Out:
# region
# กรุงเทพมหานคร            740
# ทั่วประเทศ               970
# ภาคกลาง                  954
# ภาคตะวันออกเฉียงเหนือ    910
# ภาคเหนือ                 939
# ภาคใต้                   924
# Name: region, dtype: int64

# %%
# สร้าง mapping ของค่าเดิมและค่าใหม่
region_mapping = {
    'กรุงเทพมหานคร': 1,
    'ทั่วประเทศ': 2,
    'ภาคกลาง': 3,
    'ภาคตะวันออกเฉียงเหนือ': 4,
    'ภาคเหนือ': 5,
    'ภาคใต้': 6
}

# ใช้เมธอด replace เพื่อเปลี่ยนค่าในคอลัมน์ 'region'
df['region'] = df['region'].replace(region_mapping)
df
# Out:
#       year      quarter  region  age_group             labor_force_sta  \
# 0     2561  ไตรมาสที่ 3       5         60                         รวม
# 1     2561  ไตรมาสที่ 3       5         60                     หางานทำ
# 2     2561  ไตรมาสที่ 3       5         60  ไม่หางานทำ/พร้อมที่จะทำงาน
# 3     2561  ไตรมาสที่ 4       5         60                         รวม
# 4     2561  ไตรมาสที่ 4       5         60                     หางานทำ
# ...    ...          ...     ...        ...                         ...
# 5432  2562     ไตรมาส 4       6         26                นอกเขตเทศบาล
# 5433  2563     ไตรมาส 1       6         26                นอกเขตเทศบาล
# 5434  2563     ไตรมาส 2       6         26                นอกเขตเทศบาล
# 5435  2563     ไตรมาส 3       6         26                นอกเขตเทศบาล
# 5436  2563     ไตรมาส 4       6         26                นอกเขตเทศบาล
#
#         value                 source
# 0       370.0  สำนักงานสถิติแห่งชาติ
# 1       170.0  สำนักงานสถิติแห่งชาติ
# 2       200.0  สำนักงานสถิติแห่งชาติ
# 3      1830.0  สำนักงานสถิติแห่งชาติ
# 4       110.0  สำนักงานสถิติแห่งชาติ
# ...       ...                    ...
# 5432  69120.0  สำนักงานสถิติแห่งชาติ
# 5433  51910.0  สำนักงานสถิติแห่งชาติ
# 5434  67120.0  สำนักงานสถิติแห่งชาติ
# 5435  86270.0  สำนักงานสถิติแห่งชาติ
# 5436  96140.0  สำนักงานสถิติแห่งชาติ
#
# [5437 rows x 7 columns]

# %%
df2 = df.groupby(['quarter'])['quarter'].count()
df2
# Out:
# quarter
# ไตรมาส 1        144
# ไตรมาส 2        144
# ไตรมาส 3        144
# ไตรมาส 4        144
# ไตรมาสที่ 1    1200
# ไตรมาสที่ 2    1223
# ไตรมาสที่ 3    1221
# ไตรมาสที่ 4    1217
# Name: quarter, dtype: int64

# %%
# สร้าง mapping ของค่าเดิมและค่าใหม่
quarter_mapping = {
    'ไตรมาส 1': 1,
    'ไตรมาส 2': 2,
    'ไตรมาส 3': 3,
    'ไตรมาส 4': 4,
    'ไตรมาสที่ 1': 1,
    'ไตรมาสที่ 2': 2,
    'ไตรมาสที่ 3': 3,
    'ไตรมาสที่ 4': 4
}

# ใช้เมธอด replace เพื่อเปลี่ยนค่าในคอลัมน์ 'quarter'
df['quarter'] = df['quarter'].replace(quarter_mapping)
df
# Out:
#       year  quarter  region  age_group             labor_force_sta    value  \
# 0     2561        3       5         60                         รวม    370.0
# 1     2561        3       5         60                     หางานทำ    170.0
# 2     2561        3       5         60  ไม่หางานทำ/พร้อมที่จะทำงาน    200.0
# 3     2561        4       5         60                         รวม   1830.0
# 4     2561        4       5         60                     หางานทำ    110.0
# ...    ...      ...     ...        ...                         ...      ...
# 5432  2562        4       6         26                นอกเขตเทศบาล  69120.0
# 5433  2563        1       6         26                นอกเขตเทศบาล  51910.0
# 5434  2563        2       6         26                นอกเขตเทศบาล  67120.0
# 5435  2563        3       6         26                นอกเขตเทศบาล  86270.0
# 5436  2563        4       6         26                นอกเขตเทศบาล  96140.0
#
#                      source
# 0     สำนักงานสถิติแห่งชาติ
# 1     สำนักงานสถิติแห่งชาติ
# 2     สำนักงานสถิติแห่งชาติ
# 3     สำนักงานสถิติแห่งชาติ
# 4     สำนักงานสถิติแห่งชาติ
# ...                     ...
# 5432  สำนักงานสถิติแห่งชาติ
# 5433  สำนักงานสถิติแห่งชาติ
# 5434  สำนักงานสถิติแห่งชาติ
# 5435  สำนักงานสถิติแห่งชาติ
# 5436  สำนักงานสถิติแห่งชาติ
#
# [5437 rows x 7 columns]

# %%
df2 = df.groupby(['year'])['year'].count()
df2
# Out:
# year
# 2555     64
# 2556    655
# 2557    671
# 2558    667
# 2559    668
# 2560    676
# 2561    681
# 2562    667
# 2563    688
# Name: year, dtype: int64

# %%
# สร้าง mapping ของค่าเดิมและค่าใหม่
year_mapping = {
    2555: 1,
    2556: 2,
    2557: 3,
    2558: 4,
    2559: 5,
    2560: 6,
    2561: 7,
    2562: 8,
    2563: 9
}

# ใช้เมธอด replace เพื่อเปลี่ยนค่าในคอลัมน์ 'year'
df['year'] = df['year'].replace(year_mapping)
df
# Out:
#       year  quarter  region  age_group             labor_force_sta    value  \
# 0        7        3       5         60                         รวม    370.0
# 1        7        3       5         60                     หางานทำ    170.0
# 2        7        3       5         60  ไม่หางานทำ/พร้อมที่จะทำงาน    200.0
# 3        7        4       5         60                         รวม   1830.0
# 4        7        4       5         60                     หางานทำ    110.0
# ...    ...      ...     ...        ...                         ...      ...
# 5432     8        4       6         26                นอกเขตเทศบาล  69120.0
# 5433     9        1       6         26                นอกเขตเทศบาล  51910.0
# 5434     9        2       6         26                นอกเขตเทศบาล  67120.0
# 5435     9        3       6         26                นอกเขตเทศบาล  86270.0
# 5436     9        4       6         26                นอกเขตเทศบาล  96140.0
#
#                      source
# 0     สำนักงานสถิติแห่งชาติ
# 1     สำนักงานสถิติแห่งชาติ
# 2     สำนักงานสถิติแห่งชาติ
# 3     สำนักงานสถิติแห่งชาติ
# 4     สำนักงานสถิติแห่งชาติ
# ...                     ...
# 5432  สำนักงานสถิติแห่งชาติ
# 5433  สำนักงานสถิติแห่งชาติ
# 5434  สำนักงานสถิติแห่งชาติ
# 5435  สำนักงานสถิติแห่งชาติ
# 5436  สำนักงานสถิติแห่งชาติ
#
# [5437 rows x 7 columns]

# %%
df2 = df.groupby(['labor_force_sta'])['labor_force_sta'].count()
df2
# Out:
# labor_force_sta
# นอกเขตเทศบาล                   180
# รวม                           1872
# หางานทำ                       1490
# ในเขตเทศบาล                    216
# ไม่หางานทำ/พร้อมที่จะทำงาน    1679
# Name: labor_force_sta, dtype: int64

# %%
# สร้าง mapping ของค่าเดิมและค่าใหม่
labor_mapping = {
    'นอกเขตเทศบาล': 1,
    'รวม': 2,
    'หางานทำ': 3,
    'ในเขตเทศบาล': 4,
    'ไม่หางานทำ/พร้อมที่จะทำงาน': 5
}

# ใช้เมธอด replace เพื่อเปลี่ยนค่าในคอลัม์ 'labor_force_sta'
df['labor_force_sta'] = df['labor_force_sta'].replace(labor_mapping)
df
# Out:
#       year  quarter  region  age_group  labor_force_sta    value  \
# 0        7        3       5         60                2    370.0
# 1        7        3       5         60                3    170.0
# 2        7        3       5         60                5    200.0
# 3        7        4       5         60                2   1830.0
# 4        7        4       5         60                3    110.0
# ...    ...      ...     ...        ...              ...      ...
# 5432     8        4       6         26                1  69120.0
# 5433     9        1       6         26                1  51910.0
# 5434     9        2       6         26                1  67120.0
# 5435     9        3       6         26                1  86270.0
# 5436     9        4       6         26                1  96140.0
#
#                      source
# 0     สำนักงานสถิติแห่งชาติ
# 1     สำนักงานสถิติแห่งชาติ
# 2     สำนักงานสถิติแห่งชาติ
# 3     สำนักงานสถิติแห่งชาติ
# 4     สำนักงานสถิติแห่งชาติ
# ...                     ...
# 5432  สำนักงานสถิติแห่งชาติ
# 5433  สำนักงานสถิติแห่งชาติ
# 5434  สำนักงานสถิติแห่งชาติ
# 5435  สำนักงานสถิติแห่งชาติ
# 5436  สำนักงานสถิติแห่งชาติ
#
# [5437 rows x 7 columns]

# %%
df = df.drop(columns=['source'])
df
# Out:
#       year  quarter  region  age_group  labor_force_sta    value
# 0        7        3       5         60                2    370.0
# 1        7        3       5         60                3    170.0
# 2        7        3       5         60                5    200.0
# 3        7        4       5         60                2   1830.0
# 4        7        4       5         60                3    110.0
# ...    ...      ...     ...        ...              ...      ...
# 5432     8        4       6         26                1  69120.0
# 5433     9        1       6         26                1  51910.0
# 5434     9        2       6         26                1  67120.0
# 5435     9        3       6         26                1  86270.0
# 5436     9        4       6         26                1  96140.0
#
# [5437 rows x 6 columns]

# %% [markdown]
# ทำนายอัตราคนว่างงาน

# %%
import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.preprocessing import MinMaxScaler
import pickle
from sklearn.neighbors import KNeighborsRegressor

# %%
X = df.drop(columns='value')
X
# Out:
#       year  quarter  region  age_group  labor_force_sta
# 0        7        3       5         60                2
# 1        7        3       5         60                3
# 2        7        3       5         60                5
# 3        7        4       5         60                2
# 4        7        4       5         60                3
# ...    ...      ...     ...        ...              ...
# 5432     8        4       6         26                1
# 5433     9        1       6         26                1
# 5434     9        2       6         26                1
# 5435     9        3       6         26                1
# 5436     9        4       6         26                1
#
# [5437 rows x 5 columns]

# %%
y = df['value']
y
# Out:
# 0         370.0
# 1         170.0
# 2         200.0
# 3        1830.0
# 4         110.0
#          ...
# 5432    69120.0
# 5433    51910.0
# 5434    67120.0
# 5435    86270.0
# 5436    96140.0
# Name: value, Length: 5437, dtype: float64

# %%
scaler = MinMaxScaler()

# %%
X_norm = scaler.fit_transform(X)
X_norm
# Out:
# array([[0.75      , 0.66666667, 0.8       , 1.        , 0.25      ],
#        [0.75      , 0.66666667, 0.8       , 1.        , 0.5       ],
#        [0.75      , 0.66666667, 0.8       , 1.        , 1.        ],
#        ...,
#        [1.        , 0.33333333, 1.        , 0.24444444, 0.        ],
#        [1.        , 0.66666667, 1.        , 0.24444444, 0.        ],
#        [1.        , 1.        , 1.        , 0.24444444, 0.        ]])

# %%
X_train, X_test, y_train, y_test = train_test_split( X_norm, y, test_size=0.3, random_state=42)

# %%
print("Train shape: ", X_train.shape)
print("Test shape: ", X_test.shape)
# Out:
# Train shape:  (3805, 5)
# Test shape:  (1632, 5)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# สร้างโมเดล KNN
knn = KNeighborsRegressor(n_neighbors=5)  # กำหนดจำนวนเพื่อบรรทัด k (เช่น n_neighbors=5)

# ทำการเทรนโมเดล KNN ด้วยข้อมูลการฝึกอบรม
knn.fit(X_train, y_train)

# ทำการทำนายด้วยข้อมูลทดสอบ
y_knn_pred = knn.predict(X_test)

# %%
def calculate_metrics(X, Y, model):
    pred = model.predict(X)
    mse = mean_squared_error(Y, pred)
    rmse = mse ** 0.5
    mae = mean_absolute_error(Y, pred)
    r2 = r2_score(Y, pred)

    return rmse, mae, r2

# %%
lr_rmse, lr_mae, lr_r2 = calculate_metrics(X_test, y_test, lr)
print(f"RMSE: {lr_rmse}")
print(f"MAE: {lr_mae}")
print(f"R^2: {lr_r2}")
# Out:
# RMSE: 61264.629973823816
# MAE: 30126.753422793034
# R^2: 0.0981346136196588

# %%
knn_rmse, knn_mae, knn_r2 = calculate_metrics(X_test, y_test, knn)
print(f"RMSE: {knn_rmse}")
print(f"MAE: {knn_mae}")
print(f"R^2: {knn_r2}")
# Out:
# RMSE: 44571.34464087423
# MAE: 18815.8125
# R^2: 0.5226536986900865

# %%
y_lr_pred = lr.predict(X_test[:30])
y_lr_pred
# Out:
# array([47051.84476485, 50638.98327048, 26017.0229704 , 45588.38163695,
#         9974.81337162, 24108.19519731, 22646.7623976 , 56156.95163883,
#        38786.56265165, 22712.54034218, -2703.90175042, 19989.36593072,
#        31912.08643084, 54228.25901989, 43155.77380463, 18114.50339152,
#        11859.36755702, 44328.01052131, 62958.87753971, 43376.45673085,
#        34607.72889844, 57807.61723264,  -949.3191269 , 39890.43817908,
#        17680.21294793, 12048.60035112, 16890.46692328, 26524.66603412,
#        30570.92148752, -7064.54236961])

# %%
y_knn_pred = knn.predict(X_test[:30])
y_knn_pred
# Out:
# array([ 26630., 210138.,  61808.,   5008.,  34906.,   4954.,  27740.,
#        281278.,  48674.,  41238.,   2682.,  17678.,   7598.,  96976.,
#         17378.,   9694.,   3436.,   2440.,  40290.,  72346.,  88224.,
#        210410.,   3032., 230588.,  14402.,   2528.,   6572.,   7468.,
#         29726.,    616.])

# %%
sns.lineplot(x=range(len(y_test[:30])), y=y_test[:30], label='Actual')
sns.lineplot(x=range(len(y_lr_pred[:30])), y=y_lr_pred[:30], label='Predicted Linear Regression')

plt.xlabel("Data Point")
plt.ylabel("y_test Value")
plt.figure(figsize=(12, 4))
plt.show()

# %%
sns.lineplot(x=range(len(y_test[:30])), y=y_test[:30], label='Actual')
sns.lineplot(x=range(len(y_knn_pred[:30])), y=y_knn_pred[:30], label='Predicted K-Nearest Neighbors Algorithm')

plt.xlabel("Data Point")
plt.ylabel("y_test Value")
plt.figure(figsize=(12, 4))
plt.show()

# %%
plt.figure(figsize=(12, 6))

# Plot actual data
sns.lineplot(x=range(len(y_test[:30])), y=y_test[:30], label='Actual')

# Plot predicted data for Linear Regression
sns.lineplot(x=range(len(y_lr_pred[:30])), y=y_lr_pred[:30], label='Predicted Linear Regression')

# Plot predicted data for K-Nearest Neighbors Algorithm
sns.lineplot(x=range(len(y_knn_pred[:30])), y=y_knn_pred[:30], label='K-Nearest Neighbors Algorithm')


plt.xlabel("Data Point")
plt.ylabel("y_test Value")
plt.legend()
plt.show()
